# %%
from qiskit.circuit.library import RXXGate
import numpy as np
theta = 0.7
print(np.round(RXXGate(theta).to_matrix(), 4))
# Out:
# [[ 0.9394+0.j      0.    +0.j      0.    +0.j     -0.    -0.3429j]
#  [ 0.    +0.j      0.9394+0.j     -0.    -0.3429j  0.    +0.j    ]
#  [ 0.    +0.j     -0.    -0.3429j  0.9394+0.j      0.    +0.j    ]
#  [-0.    -0.3429j  0.    +0.j      0.    +0.j      0.9394+0.j    ]]
